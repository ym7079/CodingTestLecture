# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/03_Books/03_이것이 취업을 위한 코딩 테스트다'
# Out:
# /content/drive/MyDrive/Colab Notebooks/03_Books/03_이것이 취업을 위한 코딩 테스트다

# %%
# !echo "# CodingTestLecture" >> README.md
# !git init
# !git config --global user.email "ym7079@gmail.com"
# !git config --global user.name "ym7079"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://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@github.com/ym7079/CodingTestLecture.git
# !git push -u origin main
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/03_Books/03_이것이 취업을 위한 코딩 테스트다/.git/
# [master (root-commit) 1e4c832] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md
# Counting objects: 3, done.
# Writing objects: 100% (3/3), 224 bytes | 56.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/ym7079/CodingTestLecture.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git remote rm origin

# %%
# !git add .
# !git commit -m "setup"
# !git push
# Out:
# [main 4c6356c] setup
# Counting objects: 10, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (10/10), 7.88 KiB | 807.00 KiB/s, done.
# Total 10 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), done.
# To https://github.com/ym7079/CodingTestLecture.git
#    81ac7c1..4c6356c  main -> main

# %%
# !git pull
# Out:
# Already up to date.
